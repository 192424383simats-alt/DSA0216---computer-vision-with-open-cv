# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow


image_path = "/content/l1.jpeg"
image = cv2.imread(image_path)

if image is None:
    print("Error: Image not found! Check the file path.")
    exit()

print("Original image shape:", image.shape)


gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

blur = cv2.GaussianBlur(gray, (5, 5), 0)

edges = cv2.Canny(blur, threshold1=50, threshold2=150)

contours, hierarchy = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

contour_image = image.copy()
cv2.drawContours(contour_image, contours, -1, (0, 255, 0), 2)  # green contours


print("Original Image")
cv2_imshow(image)

print("Canny Edges")
cv2_imshow(edges)

print("Contours on Image")
cv2_imshow(contour_image)


cv2.imwrite("/content/edges_canny.png", edges)
cv2.imwrite("/content/contours_image.png", contour_image)

print("Saved edges_canny.png and contours_image.png in Colab")
# Out:
# Original image shape: (148, 148, 3)
# Original Image
# <PIL.Image.Image image mode=RGB size=148x148>
# Canny Edges
# <PIL.Image.Image image mode=L size=148x148>
# Contours on Image
# <PIL.Image.Image image mode=RGB size=148x148>
# Saved edges_canny.png and contours_image.png in Colab
