# %%
import cv2
from google.colab.patches import cv2_imshow

img = cv2.imread("/content/Picture3.jpg", 0) # Corrected filename to 'photo.jpg'

if img is None:
    print("Error: Could not read the image. Please ensure 'photo.jpg' exists.")
else:
    sobel_y = cv2.Sobel(img, cv2.CV_64F, 0, 1, ksize=3)

    cv2_imshow(sobel_y) # Using cv2_imshow for Colab compatibility

    # cv2.waitKey(0) # Not needed with cv2_imshow
    # cv2.destroyAllWindows() # Not needed with cv2_imshow
# Out:
# <PIL.Image.Image image mode=L size=300x168>
